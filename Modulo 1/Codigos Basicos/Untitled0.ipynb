# %% [markdown]
# #Strings

# %% [markdown]
# sao usadas principlamente para armazenar informaçoes de texto. Nelas temos uma sequencia de caracteres que formam um texto. O python permite formar strings com aspas simples ou duplas

# %%
"Joao"=="JOAO" # o Pythn diferencia letras maiusculas de minusculas

# %%
 nome = "Beatriz"
 sobrenome = "Gomes"
 print(nome + " "+ sobrenome)

# %% [markdown]
# # f-strings

# %% [markdown]
# String literais formatadas

# %%
idade = 15

# %%
print(nome, sobrenome, idade) # as virgulas sao maneiras de chamar variaveis diferentes

# %%
print(f" {nome } {sobrenome} tem  {idade} anos,") # f na frente do print informa que estamos formatando o print

# %%
linguagem = "Python"
print(f"EU adoro programar em {linguagem}. e, amo mais ainda ganhar muito $$ programando em Python.")

# %% [markdown]
# # Strings

# %%
 nome = "Gabriel" # o Python entende uma palavra como uma lista de letras, entao podemos percorrer
  #essa lista e capturar os elementos que desejamos uma lista sempre inicia pelo indice ZERO

# %%
print(nome)

# %%
nome[0]

# %%
nome[3]

# %%
nome [-1] # podemos acessar o ultimo elemento de uma lista atraves do indice -1

# %% [markdown]
# # Entrada de dados com a funçao imput()

# %% [markdown]
# e muito comum em programaçao que o usuario passe algum tipo de dado

# %%
input("Digite seu nome:")
# Out:
# Digite seu nome:kezia
# 'kezia'

# %%
nome = input("Digite seu nome:")
# Out:
# Digite seu nome:kezia

# %%
print(nome)
# Out:
# kezia

# %%
 # Para fazer uma operaçao matematica precisamos informar qual tipo e o dado
num1 = input("Digite seu nome")
num2 = input("Digite outro numero")
print(num1 + num2)
# Out:
# Digite seu nome15
# Digite outro numero15
# 1515

# %%
# Para fazer uma operaçao matematica precisamos informar qual tipo e o dado
num1 = int(input("Digite seu nome"))
num2 = int(input("Digite outro numero"))
print(num1 + num2)
# Out:
# Digite seu nome15
# Digite outro numero15
# 30

# %%
soma = num1 + num2
print(soma)
# Out:
# 30

# %%
nota1 = float(input("Digite a primeira nota"))
nota2 = float(input("Digite a segunda nota:"))
media = (nota1+ nota2)/2
print(f"O aluno(a) teve notas {nota1}, {nota2} e a sua media e {media}.")
# Out:
# Digite a primeira nota 1.0
# Digite a segunda nota:3.0
# O aluno(a) teve notas 1.0, 3.0 e a sua media e 2.0.

# %% [markdown]
# #Operadores Arimeticos

# %%
print(10 + 20)
print(10 + 20.5)
print(10 + 30 + 40)
# Out:
# 30
# 30.5
# 80

# %%
print(-89 + 63) # print() e uma funçao de saida python
print(23 - 17) # 23 + (-17)
print(23 + (-17))
print(34 - 67) # 34 + (-67)
# Out:
# -26
# 6
# 6
# -33

# %% [markdown]
# # Subtraçao (-)

# %%
print(123-87)
# Out:
# 36

# %%
print(10*2)

# %%
print(2.4 * 2.5)

# %% [markdown]
# Divisao (/)

# %%
print(1000/10)
print(129/23)
# Out:
# 100.0
# 5.608695652173913

# %% [markdown]
# Divisao com resultado inteiro (//)

# %%
print(129//23)
# Out:
# 5

# %% [markdown]
# exponenciaçao

# %%
print(2**3)
# Out:
# 8

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(2**-1.5)
# Out:
# 0.3535533905932738

# %% [markdown]
# Precedencia

# %% [markdown]
# 1. Parenteses
# 2. Expoentes
# 3. Multiplicaçao e Divisao (da esquerda para a direita)
# 4. somas e subtraçao

# %%
5 + 25 * 2
# Out:
# 55

# %%
(5 + 25) * 2
# Out:
# 60

# %%
(12 + 3 - 1 * 50/3)
# Out:
# -1.6666666666666679

# %% [markdown]
# Radiciaçao

# %%
4**0.5
# Out:
# 2.0

# %% [markdown]
# # Hora da Pratica

# %% [markdown]
#  1) Crie um codigo que receba o nome do aluno, duas notas e informe a media do aluno. Obs: no seu print voce deve apresentar o nome do aluno, as notas e a media

# %%
nome = input("digite seu nome:")
nota1= float(input("digite a primeira nota:"))
nota2= float(input("digite a segunda nota:"))
media= (nota1 + nota2) /2
print(f"o aluno(a) teve notas {nota1}, {nota2} e sua media foi{media}")
# Out:
# digite seu nome: Kezia
# digite a primeira nota:15
# digite a segunda nota:8
# o aluno(a) teve notas 15.0, 8.0 e sua media foi11.5

# %% [markdown]
# 2) Crie um codigo que receba as medidas de um retangulo e informe o perimetro  do mesmo

# %%
vertice1= float(input("Digite a altura do retangulo :"))
vertice2= float(input("Digite a largura do retangulo:"))
perimetro = (vertice1+ vertice2) *2
print(f" o perimetro do retangulo e igual a {perimetro}")
# Out:
# Digite a altura do retangulo : 5
# Digite a largura do retangulo:20
#  o perimetro do retangulo e igual a 50.0

# %% [markdown]
# 3) Crie um codigo que calcule a raiz quadra de um numero

# %%
num1=float(input("Digite um numero:"))
raiz= num1**0.5
print(f"A raiz quadrada de {num1} e igual a {raiz}.")
# Out:
# Digite um numero:6
# A raiz quadrada de 6.0 e igual a 2.449489742783178.

# %% [markdown]
# 4) Crie uma calculadora simples (adiçao, subtraçao, multiplicaçao e divisao). seu codigo deve receber 2 numeros e apresentar o resultado das 4 opereçoes

# %%
n1= float(input("Digite um numero:"))
n2= float(input("Digite um novo numero:"))
soma= n1 + n2
subtraçao= n1- n2
multiplicaçao= n1*n2
divisao = n1/ n2
print(f"{n1}, {n2} e {soma},  {subtraçao}   {multiplicaçao}, {divisao:.2f}"
# Out:
#   File "/tmp/ipython-input-3077318259.py", line 7
#     print(f"{n1,{n2} e {soma}, {subtraçao}, {multiplicaçao}, {divisao:.2f}")
#                                                                            ^
# SyntaxError: f-string: expecting '}'

# %% [markdown]
# 5) calcule a diferença entre dois numeros

# %%
num1=float(input("digite um numero"))
num2=float(input(digite outro numero ))

# %% [markdown]
# 6) calcule o produto entre dois numeros

# %%
num1=float(input("digite um numero: "))
num2=float(input("digite outro numero:"))
produto= num1*num2
print(f"o produto entre {num1} e {num2} e {produto}")
# Out:
# digite um numero: 10
# digite outro numero:10
# o produto entre 10.0 e 10.0 e 100.0

# %% [markdown]
# 7) Crie um codigo que receba uma base e depois o expoente e calcule a potencia

# %%
num1=float(input("Digite um numero (base): "))
num2=float(input("Digite outro numero (expoente):"))
potenciacao =num1**num2
print(f"{num1} elevado ao expoente {num2} vale {potenciacao}")
# Out:
# Digite um numero (base): 10
# Digite outro numero (expoente):10
# 10.0 elevado ao expoente 10.0 vale 10000000000.0

# %% [markdown]
# 8) crie um programa que solicite ao usuario a quantidade de horaas trabalhadas por semana e o valor da hora de trabalho e calcule o salario mensal

# %%
horas=float(input("Digite o numero de horas trabalhadas:"))
valor=float(input("Digite o valor da hora trabalhada R$ "))
calculo=horas * valor
print(f"trabalhando {horas} horas voce recebera R$ {calculo}")
# Out:
# Digite o numero de horas trabalhadas:10
# Digite o valor da hora trabalhada R$ 50
# trabalhando 10.0 horas voce recebera R$ 500.0
